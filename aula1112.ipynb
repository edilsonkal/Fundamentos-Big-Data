# %% [markdown]
# ### Exercício 01 - Escreva um programa Python para desenhar uma linha com rótulo
# adequado no eixo x, eixo y e um título.
# Amostra de dados:

# %%
# importar a biblioteca
import matplotlib.pyplot as plt

x = range(1,50)
y =[value * 3 for value in x]

print('Valores de x')
print(range(1,50))
print('Valores de y (Três vezes x)')
print(y)
plt.plot(x , y)
#adicionar um titulo ao grafico
plt.title('Draw a Line' , fontsize = 15 , c= 'red')

#adicionando titulo aos eixos
plt.xlabel('Valores de x')
plt.ylabel('Valores de y')
plt.xticks(fontsize = 8, c='red')
plt.yticks(fontsize =8, c='blue' )
# Out:
# Valores de x
# range(1, 50)
# Valores de y (Três vezes x)
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160.]),
#  [Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60'),
#   Text(0, 80.0, '80'),
#   Text(0, 100.0, '100'),
#   Text(0, 120.0, '120'),
#   Text(0, 140.0, '140'),
#   Text(0, 160.0, '160')])

# %% [markdown]
# Exercício 02 - Escreva um programa Python para desenhar uma linha usando
# determinados valores de eixo com rótulo adequado no eixo x, eixo y e um título.
# Amostra de dados:

# %%
#valores do eixo x
x = [1,2,3]

#valores de y
y = [2,4,1]

#adicionar os valores ao grafico
plt.plot(x,y)

# %% [markdown]
# ### Múltiplas curvas no mecanismo gráfico

# %%
import matplotlib.pyplot as plt
import numpy as np

#Retorna ( linspace) valores iggualmente espaçados em um intervalo
x = np.linspace (0,2*np.pi,100)
y = np.sin(x)
z = np.cos(x)
plt.plot (x,y)
plt.plot (x,z)

# %%
plt.plot(x,y, label = 'seno')
plt.plot (x,z,label='cosseno')
plt.plot (x,np.sqrt(x), label='raiz quadrada')
plt.legend()

# %% [markdown]
# ### Matplotlib – Múltiplos subgráficos
# Dois gráficos na vertical (linha)

# %%
# o comando plt.subplot permite criar grupo de graficos
#plt.subplot (linhas,colunas,Posição de Elementos)

plt.subplot(2,1,1)    #primeiro garfico
plt.plot(x,y)        #conjunto de dados do primeiro graficos
plt.title('subplots')  

plt.subplot(2,1,2)     #Segundo gráfico
plt.plot(x,z)           #Conjunto de dados do segundo gráfico

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('subplots')
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
import matplotlib.pyplot as plt
import pandas as pd
#Mapear o caminho do documento

path ='C:\\Users\\FIC\\Documents\\EdilsonCarl80\\arquivo\\'
file = 'fdata.csv'
#abrir o documento
## O argumento index_col permite selecionar qual coluna será 
# o índice do dataframe exemplo: 0 - primeira coluna como índice
# 1 - segunda coluna como índice e none - padrão
df = pd.read_csv(path + file, sep = ',',index_col=None)
#Visualizador o cabeçalho
df.head()
#importar o grafico
df.plot()
# Out:
# <Axes: >

# %%
df.head()
df.columns = ['data','abertura','alta','baixa','fechamento']
df.head()
# Out:
#         data    abertura          alta          baixa  fechamento
# 0  10-03 -16     774. 25    776.065002     769.500000  772.559998
# 1   10-04-16  776.030029    778.710022     772.890015  776.429993
# 2   10-05-16  779.309998    782.070007     775.650024  776.469971
# 3   10-06-16     779.780  47998.775000  539978.000000  776.859985
# 4   10-07-16  779.659973    779.659973     770.757700    5.080017

# %%
#Selecionando colunas do dataframe
df_2 = df[['data','abertura']]
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data      5 non-null      object
#  1   abertura  5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes

# %%
# Substituir uma string

df_2['abertura'] = df_2['abertura'].replace('774. 25', '774.25')
df_2['abertura']

# Converter em Numérico pd.to_numeric(coluna)
df_2['abertura'] = pd.to_numeric(df_2['abertura'])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_15600\1392800176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['abertura'] = df_2['abertura'].replace('774. 25', '774.25')
# C:\Users\FIC\AppData\Local\Temp\ipykernel_15600\1392800176.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['abertura'] = pd.to_numeric(df_2['abertura'])

# %%
x = df_2['data']
y = df_2['abertura']

plt.plot(x , y)

# %%
df_2 = df[['alta','baixa']]
df_2.head()
# Out:
#            alta          baixa
# 0    776.065002     769.500000
# 1    778.710022     772.890015
# 2    782.070007     775.650024
# 3  47998.775000  539978.000000
# 4    779.659973     770.757700

# %%
x = df_2['alta']
y = df_2['baixa']

plt.plot(x , y)

# %%
df_2 = df[['fechamento']]
#df_2.head()
plt.plot(x ,y)

# %% [markdown]
# ### Seaborn – Gráficos mais elaborados
# Seaborn é uma biblioteca baseada em Matplolib que traz uma interface mais atraente para os gráficos,
# além de facilitar a modificação de parâmetros default do Matplotlib e permite a utilização de dataframes.
# Importando a biblioteca

# %%
#Dados ALIAS (apelido) da biblioteca SEABORN fica como sns
import seaborn as sns
import numpy as np

x =  np.linspace (0,2*np.pi,100)
y = np.sin(x)

# %% [markdown]
# ### Seaborn – Datasets embutidos
# O Seaborn possui diversos dados embutidos que podem ser utilizados para estudar a própria
# biblioteca. Para sabermos quais os datasets estão disponíveis, podemos utilizar a função
# get_datasets_names ().

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
planetas = sns.load_dataset('planets')
planetas.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
import matplotlib.pyplot as plt
sns.set()
plt.plot(x,y)

# %%
#Alterando o tema para claro
sns.set_style('whitegrid')
plt.plot(x,y)

# %%
#Alterando o tema para claro
sns.set_style('dark')
plt.plot(x,y)

# %% [markdown]
# ### Seaborn – Dados categóricos

# %%
# Graficos de Barras
sns.barplot(x='species', y='petal_length', data=iris)
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# Seaborn -Graficos estatisticos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Carregar o dataset iris da biblioteca SEABORN
iris = sns.load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Criando um histograma ´para análise univariada
sns.distplot(iris['petal_length'], kde = False)
#o kde = densidade(curva de proto)false =destiva true =ativa
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_15600\3288746850.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['petal_length'], kde = False)
# <Axes: xlabel='petal_length'>

# %%
sns.distplot(iris['petal_length'], kde = True)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_15600\4237235872.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['petal_length'], kde = True)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
#Criando uma curva de densidade
sns.distplot(iris['petal_length'], hist = False)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_15600\1598302576.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['petal_length'], hist = False)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ### Seaborn -Pairplot (bivaria)

# %%
sns.pairplot(

    iris,
    hue = 'species',     #legenda
    diag_kind= 'kde',     #tipo de gráfico de distribuição
    kind = 'scatter',     #tipo de gráfico de correlação
    palette = 'husl'    #cores
)
plt.savefig('pairplot_iris.png')
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
