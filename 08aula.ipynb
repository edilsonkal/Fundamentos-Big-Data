# %% [markdown]
# ### Exercício 04
#  Criando relatórios em função do arquivo dados-vendas.xlsx.

# %%
import pandas as pd

#mapear o local do documento fonte

caminho = 'C:\\Users\\FIC\\Documents\\EdilsonCarl80\\arquivo\\'
arquivo = 'dados-vendas.xlsx'

#Atribuir do dados deste arquivos em um dataFrame

base = pd.read_excel(caminho + arquivo,sheet_name='Vendas')

base.head()
# Out:
#     ID-Produto           Produto         Categoria     Segmento  Fabricante  \
# 0  SKU-0000001   LG K10 TV Power         Celulares  Corporativo          LG
# 1  SKU-0000002  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 2  SKU-0000003    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 3  SKU-0000004    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 4  SKU-0000005    Lavadora 11 Kg  Eletrodomésticos    Doméstico  Electrolux
#
#      Loja     Cidade     Estado          Vendedor  ID-Vendedor Data Venda  \
# 0  SP8821  São Paulo  São Paulo      Ana Teixeira         1009 2012-10-04
# 1  SP8821  São Paulo  São Paulo      Josias Silva         1006 2012-01-01
# 2  SP8821  São Paulo  São Paulo      Josias Silva         1006 2012-02-02
# 3  SP8821  São Paulo  São Paulo  Mateus Gonçalves         1003 2012-03-03
# 4  SP8821  São Paulo  São Paulo     Artur Moreira         1004 2012-04-04
#
#    ValorVenda
# 0      679.00
# 1      832.00
# 2      790.00
# 3      765.32
# 4      459.89

# %%
#Criando a tabela fato com as colunas 
df_dados = base[['ID-Produto','Loja','ID-Vendedor','Data Venda','ValorVenda']]

#renomear a coluna  loja para ID-Loja
df_dados.rename(columns={'Loja':'ID-Loja'})

df_dados.head()

#salvar o arquivo na pasta dados -vendas
caminho_novo = caminho + 'dados-vendas\\'
arquivo = 'Tabela_fato.xlsx'

df_dados.to_excel(caminho_novo + arquivo,index=False)

# %%
df_dados = base[['ID-Produto','Produto','Categoria','Segmento','Fabricante']]

df_dados.head()

caminho_novo = caminho + 'dados-vendas\\'
arquivo = 'Tabela_Produtos.xlsx'
df_dados.to_excel(caminho_novo + arquivo,index=False )

# %%
df_dados = base[['Loja','Cidade','Estado']]
#renomear coluna
df_dados = df_dados.rename(columns={'Loja':'ID_Loja'})
#remover as duplicadas
df_dados = df_dados.drop_duplicates()

df_dados.head()

caminho_novo = caminho + 'dados-vendas\\'
arquivo = 'Tabela_lojas.xlsx'
df_dados.to_excel(caminho_novo + arquivo,index=False )

# %%
df_dados = base[['ID-Vendedor;','Vendedores']]
#renomear coluna
#df_dados = df_dados.rename(columns={'Loja':'ID_Loja'})
#remover as duplicadas
#df_dados = df_dados.drop_duplicates()

df_dados.head()

caminho_novo = caminho + 'dados-vendas\\'
arquivo = 'Tabela_Vendedor.xlsx'
df_dados.to_excel(caminho_novo + arquivo,index=False )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\FIC\Documents\EdilsonCarl80\08aula.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df_dados = base[['ID-Vendedor;','Vendedores']]
#       <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> #renomear coluna
#       <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> #df_dados = df_dados.rename(columns={'Loja':'ID_Loja'})
#       <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> #remover as duplicadas
#       <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> #df_dados = df_dados.drop_duplicates()
#       <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/EdilsonCarl80/08aula.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> df_dados.head()
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['ID-Vendedor;', 'Vendedores'], dtype='object')] are in the [columns]"
